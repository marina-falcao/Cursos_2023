# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUÇÃO AO PYTHON
# ---

# %% [markdown]
# # 1.1 Introdução

# %% [markdown]
# > Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto *open source* e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
# >
# > Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado.

# %% [markdown]
# # 1.2 Instalação e ambiente de desenvolvimento

# %% [markdown]
# ### Instalação Local
#
# ### https://www.python.org/downloads/
# ### ou
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versão

# %% [markdown]
# # 1.3 Trabalhando com dados

# %%
import pandas as pd
#pd.set_option('display.max_rows', 1000)
#pd.set_option('display.max_columns', 1000)

# %%
dataset = pd.read_csv("db.csv", sep = ";")
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[["Quilometragem", "Valor"]].describe()
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABALHANDO COM TUPLAS
# ---

# %% [markdown]
# # 2.1 Criando tuplas
#
# Tuplas são sequências imutáveis que são utilizadas para armazenar coleções de itens, geralmente heterogêneos. Podem ser construídas de várias formas:
# ```
# - Utilizando um par de parênteses: ( )
# - Utilizando uma vírgula à direita: x,
# - Utilizando um par de parênteses com itens separados por vírgulas: ( x, y, z )
# - Utilizando: tuple() ou tuple(iterador)
# ```

# %%
()
# Out:
# ()

# %%
(1, 2, 3)
# Out:
# (1, 2, 3)

# %%
nome = 'Passat'
valor = 153000
(nome, valor)
# Out:
# ('Passat', 153000)

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type(nomes_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Seleções em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nomes_carros[0]
# Out:
# 'Jetta Variant'

# %%
nomes_carros[1]
# Out:
# 'Passat'

# %%
nomes_carros[-1]
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
nomes_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nomes_carros[1:2]
# Out:
# ('Passat',)

# %%
nomes_carros[-1]
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
nomes_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
for item in nomes_carros:
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
carro_1, carro_2, carro_3, carro_4 = nomes_carros #desempacotamento de tuplas:é possível atribuirmos cada valor dentro de uma tupla a uma variável específico

# %%
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DS5'

# %%
_, A, _, B = nomes_carros  #Aqui usamos as variáveis A e B para recebermos os valores das posições desejadas, e os underscores para delimitar as posições que não desejamos salvar em variáveis específicas, ignorando os seus valores.

# %%
A
# Out:
# 'Passat'

# %%
_, C, *_ = nomes_carros #podemos ignorar o primeiro valor com underscore, receber o segundo com uma variável (por exemplo C) e finalizar com asterisco seguido de underscore (*_). Dessa forma ignoraremos todos os valores posteriores.

# %%
C
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
zip(carros, valores) #cria um iterador com tuplas (de maneira semelhante à função range())

# %%
list(zip(carros, valores))   #Com o auxílio da função list(), podemos transformar esse iterador em uma lista de modo a visualizá-lo.
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for item in zip(carros, valores):  #Faremos isso usando a instrução for que irá iterar pelo resultado de zip(carros, valores). Por enquanto apenas imprimiremos as tuplas resultantes
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for carro, valor in zip(carros, valores):  # desempacotamento de tuplas, e podemos fazer isso também com o for. Aqui, ao invés de item, passaremos dois nomes separados por vírgula: carro e valor. Também passaremos a imprimir ambas as variáveis 
  print(carro, valor)
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for carro, valor in zip(carros, valores):  #incluir uma condicional if que imprime somente os carros cujo valor é maior do que 100000
  if(valor > 100000):
    print(carro)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABALHANDO COM DICIONÁRIOS
# ---

# %% [markdown]
# # 3.1 Criando dicionários
#
# Listas são coleções sequenciais, isto é, os itens destas sequências estão ordenados e utilizam índices (números inteiros) para acessar os valores.
#
# Os dicionários são coleções um pouco diferentes. São estruturas de dados que representam um tipo de mapeamento. Mapeamentos são coleções de associações entre pares de valores onde o primeiro elemento do par é conhecido como chave (*key*) e o segundo como valor (*value*).
#
# ```
# dicionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
carros.index("Passat")
# Out:
# 1

# %%
valores[carros.index("Passat")]
# Out:
# 106161.94

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
type(dados)
# Out:
# dict

# %% [markdown]
# ### Criando dicionários com *zip()*

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %%
dados = dict(list(zip(carros, valores)))
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %% [markdown]
# # 3.2 Operações com dicionários

# %% [markdown]
# ## *dict[ key ]*
#
# Retorna o valor correspondente à chave (*key*) no dicionário.

# %%
dados['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Retorna **True** se a chave (*key*) for encontrada no dicionário.

# %%
"Passat" in dados
# Out:
# True

# %%
'Fusca' in dados
# Out:
# False

# %%
'Fusca' not in dados
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Retorna o número de itens do dicionário.

# %%
len(dados)  #3 pares de chave-valor
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Inclui um item ao dicionário.

# %%
dados['DS5'] = 124549.07
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'DS5': 124549.07}

# %% [markdown]
# ## *del dict[ key ]*
#
# Remove o item de chave (*key*) do dicionário.

# %%
del dados['Passat']
dados
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'DS5': 124549.07}

# %% [markdown]
# # 3.3 Métodos de dicionários

# %% [markdown]
# ## *dict.update()*
#
# Atualiza o dicionário.

# %%
dados = dict(list(zip(carros, valores)))
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
dados.update({'Passat': 106161.94})
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
dados.update({'Passat': 106161.95, 'Fusca': 150000})
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.95,
#  'Crossfox': 72832.16,
#  'Fusca': 150000}

# %% [markdown]
# ## *dict.copy()*
#
# Cria uma cópia do dicionário.

# %%
dadosCopy = dados

# %%
dadosCopy = dados.copy()
dadosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.95,
#  'Crossfox': 72832.16,
#  'Fusca': 150000}

# %%
del dadosCopy['Fusca']
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.95, 'Crossfox': 72832.16}

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.95,
#  'Crossfox': 72832.16,
#  'Fusca': 150000}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Se a chave for encontrada no dicionário, o item é removido e seu valor é retornado. Caso contrário, o valor especificado como *default* é retornado. Se o valor *default* não for fornecido e a chave não for encontrada no dicionário um erro será gerado.

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.95, 'Crossfox': 72832.16}

# %%
dadosCopy.pop('Passat')
# Out:
# 106161.95

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16}

# %%
dadosCopy.pop('Passat')  #se vc pede pra remover algo q não tá no dict, dá erro. Pra "tratar" esse erro, ver linha abaixo com msg pro usuário
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b12fd0f355e0> in <cell line: 1>()
# ----> 1 dadosCopy.pop('Passat')
#
# KeyError: 'Passat'

# %%
dadosCopy.pop('Passat', "Chave não encontrada")
# Out:
# 'Chave não encontrada'

# %% [markdown]
# ## *dict.clear()*
#
# Remove todos os itens do dicionário.

# %%
dadosCopy.clear()

# %%
dadosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando em dicionários

# %% [markdown]
# ## *dict.keys()*
#
# Retorna uma lista contendo as chaves (*keys*) do dicionário.

# %%
dados = {'Crossfox': 72832.16, 'DS5': 124549.07,  'Fusca': 150000,  'Jetta Variant': 88078.64,  'Passat': 106161.95}
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
dados.keys()
# Out:
# dict_keys(['Crossfox', 'DS5', 'Fusca', 'Jetta Variant', 'Passat'])

# %%
for key in dados.keys():
  print(dados[key])
# Out:
# 72832.16
# 124549.07
# 150000
# 88078.64
# 106161.95

# %% [markdown]
# ## *dict.values()*
#
# Retorna uma lista com todos os valores (*values*) do dicionário.

# %%
dados.values()
# Out:
# dict_values([72832.16, 124549.07, 150000, 88078.64, 106161.95])

# %% [markdown]
# ## *dict.items()*
#
# Retorna uma lista contendo uma tupla para cada par chave-valor (*key-value*) do dicionário.

# %%
dados.items()
# Out:
# dict_items([('Crossfox', 72832.16), ('DS5', 124549.07), ('Fusca', 150000), ('Jetta Variant', 88078.64), ('Passat', 106161.95)])

# %%
for item in dados.items():
    print(item)
# Out:
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)
# ('Fusca', 150000)
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.95)

# %%
for key, value in dados.items():
    print(key, value)
# Out:
# Crossfox 72832.16
# DS5 124549.07
# Fusca 150000
# Jetta Variant 88078.64
# Passat 106161.95

# %%
for key, value in dados.items():
  if (value > 100000):
    print(key)
# Out:
# DS5
# Fusca
# Passat

# %% [markdown]
# # <font color=green> 4. FUNÇÕES E PACOTES
# ---
#
# Funções são unidades de código reutilizáveis que realizam uma tarefa específica, podem receber alguma entrada e também podem retornar alguma resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# A linguagem Python possui várias funções integradas que estão sempre acessíveis. Algumas já utilizamos em nosso treinamento: type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
valores = []     #quero somatória de valores do dicionário. Um jeito de fazer é criar uma lista de valores e depois somar

for valor in dados.values():
  valores.append(valor)
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
soma = 0                                #quero somatória de valores do dicionário. Cria variável soma e vai somando cada valor com o for
for valor in dados.values():
  soma += valor
soma

# %%
sum(dados.values()   #forma mais simples de fazer a soma
# Out:
# 267072.74

# %%
sum(dados.values(), 1000000)  #esse valor extra na fórmula é um valor inicial de soma
# Out:
# 1267072.7399999998

# %%
help(print) #forma de pedir ajuda sobre função
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print? #outra forma de pedir ajuda sobre função

# %% [markdown]
# # 4.2 Definindo funções sem e com parâmetros

# %% [markdown]
# ### Funções sem parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>():
#     <instruções>
# ```

# %%
def media():
    valor = (1 + 2 + 3) / 3
    print(valor)

media()
# Out:
# 2.0

# %% [markdown]
# ### Funções com parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
# ```

# %%
def media(number_1, number_2, number_3):
  valor = (number_1 + number_2 +number_3) / 3
  print(valor)

# %%
media(1,2,3)
# Out:
# 2.0

# %%
media(23, 45, 67)
# Out:
# 45.0

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  print(valor)

# %%
media ([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 5.0

# %% [markdown]
# # 4.3 Definindo funções que retornam valores

# %% [markdown]
# ### Funções que retornam um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return <resultado>
# ```

# %%
def media(lista):                #o print só mostra o valor no final da função, já o return permite que esse valor final possa ser atribuido a uma variável
  valor = sum(lista) / len(lista)
  return valor

# %%
media([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 4.5

# %%
resultado = media([1, 2, 3, 4, 5, 6, 7, 8])
resultado
# Out:
# 4.5

# %% [markdown]
# ### Funções que retornam mais de um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return (valor, len(lista))

# %%
resultado = media([1, 2, 3, 4, 5, 6, 7, 8])
resultado
# Out:
# (4.5, 8)

# %%
resultado, n = media([1, 2, 3, 4, 5, 6, 7, 8, 9])
resultado
# Out:
# 5.0

# %%
n
# Out:
# 9

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versão: 0.25.2**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy. O pacote pandas possui estruturas de dados bastante interessantes para manipulação de dados e por isso é muito utilizado por cientistas de dados.
#
#
# ## Estruturas de Dados
#
# ### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte:
#
#
# ```
#     s = pd.Series(dados, index = index)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# ### DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#
# ```
#     df = pd.DataFrame(dados, index = index, columns = columns)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# **Documentação:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# # 5.1 Estruturas de dados

# %%
import pandas as pd

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
s = pd.Series(carros)

# %%
s
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(dados)   #Criaremos então uma variável dataset que receberá a chamada de pd.DataFrame() passando como parâmetro nossa lista dados
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
dataset[['Nome', 'Ano', 'Motor', 'Quilometragem', 'Zero_km', 'Valor']]  #mudar ordem das colunas
# Out:
#             Nome   Ano            Motor  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  2003  Motor 4.0 Turbo        44410.0    False   88078.64
# 1         Passat  1991     Motor Diesel         5712.0    False  106161.94
# 2       Crossfox  1990  Motor Diesel V8        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de uma arquivo externo

# %%
dataset = pd.read_csv('db.csv', sep = ';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset = pd.read_csv('db.csv', sep = ';', index_col = 0)  #a coluna 0 virou index e fica embutida
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %% [markdown]
# # 5.2 Seleções com DataFrames

# %% [markdown]
# ### Selecionando colunas

# %%
dataset.head(10)
# Out:
#                                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant           Motor 4.0 Turbo  2003        44410.0    False
# Passat                     Motor Diesel  1991         5712.0    False
# Crossfox                Motor Diesel V8  1990        37123.0    False
# DS5                     Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0    False
# Palio Weekend             Motor 1.8 16v  2012        10728.0    False
# A5                      Motor 4.0 Turbo  2019            NaN     True
# Série 3 Cabrio             Motor 1.0 8v  2009        77599.0    False
# Dodge Jorney              Motor 3.0 32v  2010        99197.0    False
# Carens            Motor 5.0 V8 Bi-Turbo  2011        37978.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# ...

# %%
dataset['Valor']
# Out:
# Nome
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]   #l selecionar uma única coluna e obter como retorno um dataframe. Para isso, ao invés de passarmos um único par de colchetes, passaremos dois.
# Out:
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-f362a5fdbf5e> in <cell line: 1>()
# ----> 1 type(dataset([['Valor']]))
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ### Selecionando linhas - [ i : j ]
#
# <font color=red>**Observação:**</font> A indexação tem origem no zero e nos fatiamentos (*slices*) a linha com índice i é **incluída** e a linha com índice j **não é incluída** no resultado.

# %%
dataset[0:3]
# Out:
#                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# Passat            Motor Diesel  1991         5712.0    False
# Crossfox       Motor Diesel V8  1990        37123.0    False
#
#                                                       Acessórios      Valor
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat         ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox       ['Piloto automático', 'Controle de estabilidad...   72832.16

# %% [markdown]
# ### Utilizando .loc para seleções
#
# <font color=red>**Observação:**</font> Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
dataset.loc['Passat']  #retorna series com info da linha do passat
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'DS5']]  #retorna dataframe
# Out:
#                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat     Motor Diesel  1991         5712.0    False
# DS5     Motor 2.4 Turbo  2019            NaN     True
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# DS5     ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.loc[['Passat', 'DS5'], ['Motor', 'Valor']]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
dataset.loc[:, ['Motor', 'Valor']]
# Out:
#                                        Motor      Valor
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Utilizando .iloc para seleções
#
# <font color=red>**Observação:**</font> Seleciona com base nos índices, ou seja, se baseia na posição das informações.

# %%
dataset.iloc[1] #mas se utiliza dos índices numéricos - ou seja, na posição das informações.
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.iloc[[1]]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[1:4]
# Out:
#                     Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat       Motor Diesel  1991         5712.0    False
# Crossfox  Motor Diesel V8  1990        37123.0    False
# DS5       Motor 2.4 Turbo  2019            NaN     True
#
#                                                  Acessórios      Valor
# Nome
# Passat    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox  ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5       ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.iloc[1:4, [0, 5, 2]]  #seleciona linhas 1 a 3 e colunas 0, 5 e 2
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %%
dataset.iloc[[1, 42, 22], [0, 5, 2]]
# Out:
#                                Motor      Valor  Quilometragem
# Nome
# Passat                  Motor Diesel  106161.94         5712.0
# Optima                 Motor 1.8 16v   86641.34            NaN
# Lamborghini Obvious  Motor Diesel V6  133529.84        98079.0

# %%
dataset.iloc[:, [0, 5, 2]]
# Out:
#                                        Motor      Valor  Quilometragem
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64        44410.0
# Passat                          Motor Diesel  106161.94         5712.0
# Crossfox                     Motor Diesel V8   72832.16        37123.0
# DS5                          Motor 2.4 Turbo  124549.07            NaN
# Aston Martin DB4             Motor 2.4 Turbo   92612.10        25757.0
# ...                                      ...        ...            ...
# Phantom 2013                        Motor V8   51759.58        27505.0
# Cadillac Ciel concept               Motor V8   51667.06        29981.0
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03        52637.0
# Aston Martin DB5                Motor Diesel  122110.90         7685.0
# Macan                        Motor Diesel V6   90381.47        50188.0
#
# [258 rows x 3 columns]

# %% [markdown]
# # 5.3 Queries com DataFrames

# %%
dataset = pd.read_csv('db.csv', sep = ';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
select = dataset.Motor == 'Motor Diesel'
select
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 253    False
# 254    False
# 255    False
# 256     True
# 257    False
# Name: Motor, Length: 258, dtype: bool

# %%
dataset[select]  #uma query (consulta) q traz só os carros com motor a diesel
# Out:
#                       Nome         Motor   Ano  Quilometragem  Zero_km  \
# 1                   Passat  Motor Diesel  1991         5712.0    False
# 23   Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# 60                 Sorento  Motor Diesel  2019            NaN     True
# 62        New Fiesta Hatch  Motor Diesel  2017       118895.0    False
# 69          Kangoo Express  Motor Diesel  2007        29132.0    False
# 74                     Fit  Motor Diesel  2013        44329.0    False
# 78             Cielo Hatch  Motor Diesel  2019            NaN     True
# 86                  Symbol  Motor Diesel  2016       117714.0    False
# 89                A4 Sedan  Motor Diesel  2002        30511.0    False
# 111               A4 Avant  Motor Diesel  2014        17357.0    False
# 119          Silver Shadow  Motor Diesel  2015        99052.0    False
# 124                  Camry  Motor Diesel  2019            NaN     True
# ...

# %%
dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)]  #carros com motor a diesel e 0km - query
# Out:
#                     Nome         Motor   Ano  Quilometragem  Zero_km  \
# 60               Sorento  Motor Diesel  2019            NaN     True
# 78           Cielo Hatch  Motor Diesel  2019            NaN     True
# 124                Camry  Motor Diesel  2019            NaN     True
# 189  Aston Martin Virage  Motor Diesel  2019            NaN     True
# 237         Série 7 Sedã  Motor Diesel  2019            NaN     True
#
#                                             Acessórios      Valor
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79

# %% [markdown]
# ### Utilizando o método query

# %%
dataset.query('Motor == "Motor Diesel" and Zero_km == True') #outra forma de trazer carros com motor a diesel e 0km - query
# Out:
#                     Nome         Motor   Ano  Quilometragem  Zero_km  \
# 60               Sorento  Motor Diesel  2019            NaN     True
# 78           Cielo Hatch  Motor Diesel  2019            NaN     True
# 124                Camry  Motor Diesel  2019            NaN     True
# 189  Aston Martin Virage  Motor Diesel  2019            NaN     True
# 237         Série 7 Sedã  Motor Diesel  2019            NaN     True
#
#                                             Acessórios      Valor
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79

# %%
dataset[(dataset.Motor == 'Motor Diesel') | (dataset.Zero_km == True)]
# Out:
#                  Nome            Motor   Ano  Quilometragem  Zero_km  \
# 1              Passat     Motor Diesel  1991         5712.0    False
# 3                 DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                  A5  Motor 4.0 Turbo  2019            NaN     True
# 13                 J5         Motor V6  2019            NaN     True
# 17                 A3     Motor 1.0 8v  2019            NaN     True
# ..                ...              ...   ...            ...      ...
# 242        Benni Mini         Motor V8  2019            NaN     True
# 243               Uno  Motor Diesel V6  2019            NaN     True
# 245          Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248              XC60  Motor 4.0 Turbo  2019            NaN     True
# 256  Aston Martin DB5     Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# ...

# %%
dataset.query('Motor == "Motor Diesel" or Zero_km == True')
# Out:
#                  Nome            Motor   Ano  Quilometragem  Zero_km  \
# 1              Passat     Motor Diesel  1991         5712.0    False
# 3                 DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                  A5  Motor 4.0 Turbo  2019            NaN     True
# 13                 J5         Motor V6  2019            NaN     True
# 17                 A3     Motor 1.0 8v  2019            NaN     True
# ..                ...              ...   ...            ...      ...
# 242        Benni Mini         Motor V8  2019            NaN     True
# 243               Uno  Motor Diesel V6  2019            NaN     True
# 245          Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248              XC60  Motor 4.0 Turbo  2019            NaN     True
# 256  Aston Martin DB5     Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# ...

# %% [markdown]
# # 5.4 Iterando com DataFrames

# %%
for item in dataset:
    print(item)
# Out:
# Nome
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
list(dataset.iterrows())
# Out:
# [(0,
#   Nome                                                 Jetta Variant
#   Motor                                              Motor 4.0 Turbo
#   Ano                                                           2003
#   Quilometragem                                              44410.0
#   Zero_km                                                      False
#   Acessórios       ['Rodas de liga', 'Travas elétricas', 'Piloto ...
#   Valor                                                     88078.64
#   Name: 0, dtype: object),
#  (1,
#   Nome                                                        Passat
#   Motor                                                 Motor Diesel
#   Ano                                                           1991
#   Quilometragem                                               5712.0
#   Zero_km                                                      False
#   Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# ...

# %%
for index, row in dataset.iterrows():
  if(2019 - row['Ano'] != 0):
    dataset.loc[index, 'Km_media'] = row['Quilometragem'] / (2019 - row['Ano'])
  else:
    dataset.loc[index, 'Km_media'] = 0

dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# ...

# %% [markdown]
# # 5.5 Tratamento de dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
#  7   Km_media       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(3)
# memory usage: 14.5+ KB

# %%
dataset.Quilometragem.isna()  #selecionar informações nulas ou não, quais valores são ou não "NA", Quando os valores são NA, são identificados na series como True
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()] #seletor pra ver os casos nulos
# Out:
#                      Nome            Motor   Ano  Quilometragem  Zero_km  \
# 3                     DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                      A5  Motor 4.0 Turbo  2019            NaN     True
# 13                     J5         Motor V6  2019            NaN     True
# 17                     A3     Motor 1.0 8v  2019            NaN     True
# 21              Série 1 M         Motor V8  2019            NaN     True
# ..                    ...              ...   ...            ...      ...
# 238  Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# 242            Benni Mini         Motor V8  2019            NaN     True
# 243                   Uno  Motor Diesel V6  2019            NaN     True
# 245              Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248                  XC60  Motor 4.0 Turbo  2019            NaN     True
#
#                                             Acessórios      Valor  Km_media
# ...

# %%
dataset.fillna(0)  #retorno nosso dataset com os valores NA preenchidos como 0. Essa alteração não refletirá no nosso dataset original, já que apenas modificamos a visualização dele
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            0.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# ...

# %%
dataset.fillna(0, inplace = True) #esse inplace altera o dataset

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            0.0     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor     Km_media
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64  2775.625000
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94   204.000000
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16  1280.103448
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07     0.000000
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10  1981.307692

# %%
dataset.query('Zero_km == True')
# Out:
#                      Nome            Motor   Ano  Quilometragem  Zero_km  \
# 3                     DS5  Motor 2.4 Turbo  2019            0.0     True
# 6                      A5  Motor 4.0 Turbo  2019            0.0     True
# 13                     J5         Motor V6  2019            0.0     True
# 17                     A3     Motor 1.0 8v  2019            0.0     True
# 21              Série 1 M         Motor V8  2019            0.0     True
# ..                    ...              ...   ...            ...      ...
# 238  Lamborghini Reventón  Motor 4.0 Turbo  2019            0.0     True
# 242            Benni Mini         Motor V8  2019            0.0     True
# 243                   Uno  Motor Diesel V6  2019            0.0     True
# 245              Santa Fe    Motor 3.0 32v  2019            0.0     True
# 248                  XC60  Motor 4.0 Turbo  2019            0.0     True
#
#                                             Acessórios      Valor  Km_media
# ...

# %%
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset.dropna(subset = ['Quilometragem'])   #ferramenta do Pandas que nos ajuda a eliminar os valores nulos de um dataframe, chamada dropna().todos os registros que contêm esse valor serão eliminados completamente (ou seja, toda a linha será removida)
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# 5            Palio Weekend          Motor 1.8 16v  2012        10728.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.dropna(subset = ['Quilometragem'], inplace = True)
