# %%
nome = 'Luiza'

# %%
def saudacao_com_parametros(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametros(nome)
# Out:
# Olá Luiza

# %%
idade = 20

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
   print('Tem permissão para dirigir')
  else:
     print("Não tem permissão para dirigir.")

# %%
verifica_se_pode_dirigir(20)
# Out:
# Tem permissão para dirigir

# %%
verifica_se_pode_dirigir(15)
# Out:
# Não tem permissão para dirigir.

# %%
def verifica_se_pode_dirigir_sem_parametro():
    idade = int(input('Qual sua idade'))
    if idade >= 18:
        print('Tem permissão para dirigir')
    else:
        print('Não tem permissão para dirigir')


verifica_se_pode_dirigir_sem_parametro()
# Out:
# Qual sua idade18
# Tem permissão para dirigir

# %%
verifica_se_pode_dirigir_sem_parametro()
# Out:
# Qual sua idade12
# Não tem permissão para dirigir

# %%
idades = [18, 22, 15, 50 ]

# %%
idades[0:2]
# Out:
# [18, 22]

# %%
idades[1:]
# Out:
# [22, 15, 50]

# %%
idades[-1]
# Out:
# 50

# %%
def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'{idade} anos de idade, TEM permissão para dirigir')
  else:
    print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')

# %%
for idade in idades: 
  verifica_se_pode_dirigir(idade)
# Out:
# 18 anos de idade, TEM permissão para dirigir
# 22 anos de idade, TEM permissão para dirigir
# 15 anos de idade, NÃO TEM permissão para dirigir
# 50 anos de idade, TEM permissão para dirigir

# %%
def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18:
      print(f'{idade} anos de idade, TEM permissão para dirigir')
    else:
      print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')

# %%
verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade, TEM permissão para dirigir
# 22 anos de idade, TEM permissão para dirigir
# 15 anos de idade, NÃO TEM permissão para dirigir
# 50 anos de idade, TEM permissão para dirigir

# %%
permissoes = []
idades = [20, 14, 40]

# %%
def verifica_se_pode_dirigir(idades, permissoes):
    for idade in idades:
      if idade >= 18:
          permissoes.append(True)
      else:
          permissoes.append(False)

# %%
verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('Tem permissão para dirigir')
  else:
    print('Não tem permissão para dirigir')
# Out:
# Tem permissão para dirigir
# Não tem permissão para dirigir
# Tem permissão para dirigir

# %%
lista = ['Guilherme', 28, True, '18']

for elemento in lista: 
  print(f'O elemento {elemento} é do tipo: ', type(elemento))
# Out:
# O elemento Guilherme é do tipo:  <class 'str'>
# O elemento 28 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 18 é do tipo:  <class 'str'>

# %%
from random import randrange, seed

# %%
seed(11)

# %%
randrange(0,11)
# Out:
# 7

# %%
randrange(0,11)
# Out:
# 8

# %%
notas_matematica = []

for notas in range(8):
    notas_matematica.append([randrange(0,11)])

# %%
notas_matematica
# Out:
# [[7], [7], [8], [9], [3], [2], [8], [7]]

# %%
notas_matematica
# Out:
# [[7], [7], [8], [9], [3], [2], [8], [7]]

# %%
import matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1,9))   #quero ver os números das 8 provas no eixo x
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
y = notas_matematica  #quero ver as notas das 8 provas no eixo y
y
# Out:
# [[7], [7], [8], [9], [3], [2], [8], [7]]

# %%
x = list(range(1,9))
y = notas_matematica

# %%
x = list(range(1,9))
y = notas_matematica
plt.plot(x, y, marker="o")     #cria gráfico plot, com bolinha em cada nota
plt.title("Notas de Matemática")  #muda título
plt.xlabel("Provas")             #muda eixo x
plt.ylabel("Notas")               #muda eixo y
plt.show()
